# %% [markdown]
# # this dataset is the wordwar 3

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\datasets\iran_war_gas_prices_by_state.csv")

df.head()
# Out:
#         state region  gas_price_mar19_2026  gas_price_prewar_feb27  \
# 0  California   West                  5.53                    4.52
# 1  Washington   West                  5.15                    4.18
# 2      Hawaii   West                  5.07                    4.02
# 3      Oregon   West                  4.70                    3.82
# 4      Nevada   West                  4.66                    3.72
#
#    gas_price_jan08_2026  price_increase_since_war  pct_increase_since_war  \
# 0                  3.88                      1.01                    22.3
# 1                  3.42                      0.97                    23.2
# 2                  3.78                      1.05                    26.1
# 3                  3.22                      0.88                    23.0
# 4                  3.18                      0.94                    25.3
#
#    price_vs_national_avg                                         source
# ...

# %%
df.tail()
# Out:
#           state region  gas_price_mar19_2026  gas_price_prewar_feb27  \
# 45  Mississippi  South                  3.38                    2.64
# 46     Arkansas  South                  3.42                    2.66
# 47    Louisiana  South                  3.46                    2.70
# 48        Texas  South                  3.48                    2.72
# 49     Oklahoma  South                  3.24                    2.54
#
#     gas_price_jan08_2026  price_increase_since_war  pct_increase_since_war  \
# 45                  2.34                      0.74                    28.0
# 46                  2.36                      0.76                    28.6
# 47                  2.40                      0.76                    28.1
# 48                  2.44                      0.76                    27.9
# 49                  2.28                      0.70                    27.6
#
#     price_vs_national_avg                                         source
# ...

# %%
df.isnull().sum()
# Out:
# state                       0
# region                      0
# gas_price_mar19_2026        0
# gas_price_prewar_feb27      0
# gas_price_jan08_2026        0
# price_increase_since_war    0
# pct_increase_since_war      0
# price_vs_national_avg       0
# source                      0
# dtype: int64

# %%
df.tail()
# Out:
#           state region  gas_price_mar19_2026  gas_price_prewar_feb27  \
# 45  Mississippi  South                  3.38                    2.64
# 46     Arkansas  South                  3.42                    2.66
# 47    Louisiana  South                  3.46                    2.70
# 48        Texas  South                  3.48                    2.72
# 49     Oklahoma  South                  3.24                    2.54
#
#     gas_price_jan08_2026  price_increase_since_war  pct_increase_since_war  \
# 45                  2.34                      0.74                    28.0
# 46                  2.36                      0.76                    28.6
# 47                  2.40                      0.76                    28.1
# 48                  2.44                      0.76                    27.9
# 49                  2.28                      0.70                    27.6
#
#     price_vs_national_avg                                         source
# ...

# %%
df['state']
# Out:
# 0         California
# 1         Washington
# 2             Hawaii
# 3             Oregon
# 4             Nevada
# 5            Arizona
# 6             Alaska
# 7               Utah
# 8              Idaho
# 9            Montana
# 10           Wyoming
# 11          Colorado
# 12        New Mexico
# 13          Illinois
# 14          Michigan
# 15              Ohio
# 16           Indiana
# 17         Wisconsin
# 18         Minnesota
# 19              Iowa
# 20          Missouri
# 21      North Dakota
# 22      South Dakota
# 23          Nebraska
# 24            Kansas
# 25          New York
# 26     Massachusetts
# 27       Connecticut
# 28        New Jersey
# 29      Pennsylvania
# 30      Rhode Island
# 31           Vermont
# 32     New Hampshire
# 33             Maine
# 34          Maryland
# 35          Delaware
# 36          Virginia
# 37    North Carolina
# 38    South Carolina
# 39           Georgia
# 40           Florida
# 41         Tennessee
# 42          Kentucky
# ...

# %%
df['region']
# Out:
# 0          West
# 1          West
# 2          West
# 3          West
# 4          West
# 5          West
# 6          West
# 7          West
# 8          West
# 9          West
# 10         West
# 11         West
# 12         West
# 13      Midwest
# 14      Midwest
# 15      Midwest
# 16      Midwest
# 17      Midwest
# 18      Midwest
# 19      Midwest
# 20      Midwest
# 21      Midwest
# 22      Midwest
# 23      Midwest
# 24      Midwest
# 25    Northeast
# 26    Northeast
# 27    Northeast
# 28    Northeast
# 29    Northeast
# 30    Northeast
# 31    Northeast
# 32    Northeast
# 33    Northeast
# 34    Northeast
# 35    Northeast
# 36        South
# 37        South
# 38        South
# 39        South
# 40        South
# 41        South
# 42        South
# 43        South
# 44        South
# 45        South
# 46        South
# 47        South
# 48        South
# 49        South
# Name: region, dtype: object

# %%
plt.plot(df['gas_price_mar19_2026'] )
