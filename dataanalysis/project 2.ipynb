# %% [markdown]
# # without using matplotlib we work with open cv

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread(r'C:\Users\niles\OneDrive\Pictures\134118367428608576.jpg')
img
# Out:
# array([[[253, 232, 194],
#         [252, 231, 193],
#         [251, 230, 192],
#         ...,
#         [253, 234, 191],
#         [249, 232, 189],
#         [252, 235, 192]],
#
#        [[253, 230, 192],
#         [253, 230, 192],
#         [253, 230, 192],
#         ...,
#         [250, 231, 188],
#         [247, 230, 187],
#         [250, 233, 190]],
#
#        [[255, 229, 192],
#         [255, 229, 192],
#         [255, 230, 193],
#         ...,
#         [249, 230, 187],
#         [247, 231, 185],
#         [252, 236, 190]],
#
#        ...,
#
#        [[ 30,  26,  21],
#         [ 29,  25,  20],
#         [ 31,  27,  22],
#         ...,
#         [ 22,  25,  23],
#         [ 23,  26,  24],
#         [ 23,  26,  24]],
#
#        [[ 31,  27,  22],
#         [ 29,  25,  20],
#         [ 32,  28,  23],
#         ...,
#         [ 22,  25,  23],
#         [ 22,  25,  23],
#         [ 21,  24,  22]],
#
#        [[ 33,  29,  24],
#         [ 30,  26,  21],
#         [ 32,  28,  23],
# ...

# %%
wrong_img = cv2.imread(r'C:\Users\niles\OneDrive\Pictures\dog.jpg')#inbuild function(imread) is never give any error eithor thay are wrong in the imag

# %%
type(wrong_img)
# Out:
# NoneType

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img = cv2.imread(r'C:\Users\niles\OneDrive\Pictures\134118367428608576.jpg')
img                           # in this "myimag " the changing the heading in show image in othor platfor
cv2.imshow('myimag',img) 
cv2.waitKey() # in waitkey means when the user not close the windoe of imsge that will show the image popup
# Out:
# -1

# %%
import cv2

img= cv2.imread(r'C:\Users\niles\OneDrive\Pictures\134118367428608576.jpg')

while True:
    cv2.imshow('my image',img)

    if cv2.waitKey(1) & 0xFF==27:
        break
cv2.destroyAllWindows()
