# %% [markdown]
# # discriptive statistics

# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\niles\Downloads\Inc_Exp_Data.csv")

# %%
df
# Out:
#     Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 0              5000              8000                  3             2000
# 1              6000              7000                  2             3000
# 2             10000              4500                  2                0
# 3             10000              2000                  1                0
# 4             12500             12000                  2             3000
# 5             14000              8000                  2                0
# 6             15000             16000                  3            35000
# 7             18000             20000                  5             8000
# 8             19000              9000                  2                0
# 9             20000              9000                  4                0
# 10            20000             18000                  4             8000
# 11            22000             25000                  6            12000
# ...

# %%
df.describe()
# Out:
#        Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# count        50.000000         50.000000          50.000000        50.000000
# mean      41558.000000      18818.000000           4.060000      3060.000000
# std       26097.908979      12090.216824           1.517382      6241.434948
# min        5000.000000       2000.000000           1.000000         0.000000
# 25%       23550.000000      10000.000000           3.000000         0.000000
# 50%       35000.000000      15500.000000           4.000000         0.000000
# 75%       50375.000000      25000.000000           5.000000      3500.000000
# max      100000.000000      50000.000000           7.000000     35000.000000
#
#        Annual_HH_Income  No_of_Earning_Members
# count      5.000000e+01              50.000000
# mean       4.900190e+05               1.460000
# std        3.201358e+05               0.734291
# min        6.420000e+04               1.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Mthly_HH_Income           50 non-null     int64
#  1   Mthly_HH_Expense          50 non-null     int64
#  2   No_of_Fly_Members         50 non-null     int64
#  3   Emi_or_Rent_Amt           50 non-null     int64
#  4   Annual_HH_Income          50 non-null     int64
#  5   Highest_Qualified_Member  50 non-null     object
#  6   No_of_Earning_Members     50 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 2.9+ KB

# %%
df.isnull().sum()
# Out:
# Mthly_HH_Income             0
# Mthly_HH_Expense            0
# No_of_Fly_Members           0
# Emi_or_Rent_Amt             0
# Annual_HH_Income            0
# Highest_Qualified_Member    0
# No_of_Earning_Members       0
# dtype: int64

# %%
df.head()
# Out:
#    Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 0             5000              8000                  3             2000
# 1             6000              7000                  2             3000
# 2            10000              4500                  2                0
# 3            10000              2000                  1                0
# 4            12500             12000                  2             3000
#
#    Annual_HH_Income Highest_Qualified_Member  No_of_Earning_Members
# 0             64200           Under-Graduate                      1
# 1             79920               Illiterate                      1
# 2            112800           Under-Graduate                      1
# 3             97200               Illiterate                      1
# 4            147000                 Graduate                      1

# %%
df.describe().T
# Out:
#                        count       mean            std      min       25%  \
# Mthly_HH_Income         50.0   41558.00   26097.908979   5000.0   23550.0
# Mthly_HH_Expense        50.0   18818.00   12090.216824   2000.0   10000.0
# No_of_Fly_Members       50.0       4.06       1.517382      1.0       3.0
# Emi_or_Rent_Amt         50.0    3060.00    6241.434948      0.0       0.0
# Annual_HH_Income        50.0  490019.04  320135.792123  64200.0  258750.0
# No_of_Earning_Members   50.0       1.46       0.734291      1.0       1.0
#
#                             50%       75%        max
# Mthly_HH_Income         35000.0   50375.0   100000.0
# Mthly_HH_Expense        15500.0   25000.0    50000.0
# No_of_Fly_Members           4.0       5.0        7.0
# Emi_or_Rent_Amt             0.0    3500.0    35000.0
# Annual_HH_Income       447420.0  594720.0  1404000.0
# No_of_Earning_Members       1.0       2.0        4.0

# %%
df.shape
# Out:
# (50, 7)

# %%
df.isna().any()
# Out:
# Mthly_HH_Income             False
# Mthly_HH_Expense            False
# No_of_Fly_Members           False
# Emi_or_Rent_Amt             False
# Annual_HH_Income            False
# Highest_Qualified_Member    False
# No_of_Earning_Members       False
# dtype: bool

# %% [markdown]
# # what is the mean expance of a houisehold

# %%
df['Mthly_HH_Expense'].mean()
# Out:
# np.float64(18818.0)

# %%
df['Mthly_HH_Expense'].median()
# Out:
# np.float64(15500.0)

# %%
nth_exp_temp=pd.crosstab(index=df['Mthly_HH_Expense'],columns='count')
nth_exp_temp.reset_index(inplace=True)
nth_exp_temp[nth_exp_temp['count']==df.Mthly_HH_Expense.value_counts().max()]
# Out:
# col_0  Mthly_HH_Expense  count
# 18                25000      8

# %% [markdown]
# # what is the month;y expances for most of the household

# %%
df['Highest_Qualified_Member'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Highest_Qualified_Member'>

# %% [markdown]
# # iqr

# %%
df.plot(x='Mthly_HH_Income',y='Mthly_HH_Expense')
iqr=df['Mthly_HH_Expense'].quantile(0.75)-df['Mthly_HH_Expense'].quantile(0.25)
iqr
# Out:
# np.float64(15000.0)

# %% [markdown]
# # calculate the count hhighest qualified members

# %%
df['Highest_Qualified_Member'].value_counts().to_frame().T
# Out:
# Highest_Qualified_Member  Graduate  Under-Graduate  Professional  \
# count                           19              10            10
#
# Highest_Qualified_Member  Post-Graduate  Illiterate
# count                                 6           5

# %% [markdown]
# # plot the histogram to count the no fo earnings members

# %%
df['No_of_Earning_Members'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='No_of_Earning_Members'>

# %% [markdown]
# # inferential statistics

# %%
import sys

# %%
pwd
# Out:
# 'C:\\Users\\niles'

# %% [markdown]
# # connecting the python with mysql

# %%
import mysql.connector
conn =mysql.connector.connect(host='localhost',user='root',password='081908')
if conn.is_connected():
	print('connection establish')
print(conn)
print(conn.is_connected)
# Out:
# connection establish
# ...
# <bound method MySQLConnection.is_connected of <mysql.connector.connection.MySQLConnection object at 0x00000267C40A57F0>>

# %% [markdown]
# # show databses

# %%
import mysql.connector
conn =mysql.connector.connect(host='localhost',user='root',password='081908')
mycursor=conn.cursor()
mycursor.execute('show databases')
for x in mycursor:
    print(x)
# Out:
# ('customers',)
# ('customers_ind',)
# ('customers_us',)
# ('dept',)
# ('emp',)
# ('employee',)
# ('information_schema',)
# ('lab',)
# ('mydb',)
# ('mysql',)
# ('nit',)
# ('orders',)
# ('performance_schema',)
# ('sell',)
# ('stocks',)
# ('student',)
# ('studentmanagement',)
# ('sys',)

# %%
import mysql.connector
conn =mysql.connector.connect(host='localhost',user='root',password='081908')
if conn.is_connected():
    print("connection established")
mycursor=conn.cursor()
mycursor.execute('create database pythondb')
print(mycursor)
# Out:
# connection established
# MySQLCursor: create database pythondb

# %%
import mysql.connector

conn = mysql.connector.connect(
    host='localhost',
    user='root',
    password='081908',
    database='pythondb'
)

mycursor = conn.cursor()

# Create table
mycursor.execute('CREATE TABLE student(name VARCHAR(50), branch VARCHAR(50), id INT)')

# Show tables
mycursor.execute('SHOW TABLES')

for x in mycursor:
    print(x)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[27], line 13
#      10 mycursor = conn.cursor()
#      12 # Create table
# ---> 13 mycursor.execute('CREATE TABLE student(name VARCHAR(50), branch VARCHAR(50), id INT)')
#      15 # Show tables
#      16 mycursor.execute('SHOW TABLES')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\mysql\connector\cursor.py:416, in MySQLCursor.execute(self, operation, params, map_results)
#     408 self._executed_list = self._stmt_partition["single_stmts"]
#     409 self._executed = (
#     410     self._stmt_partition["single_stmts"].popleft()
#     411     if map_results
#     412     else self._stmt_partition["mappable_stmt"]
#     413 )
#     415 self._handle_result(
# --> 416     self._connection.cmd_query(
# ...

# %%
mycursor.execute('DESCRIBE student')
for x in mycursor:
    print(x)
# Out:
# ('name', 'varchar(50)', 'YES', '', None, '')
# ('branch', 'varchar(50)', 'YES', '', None, '')
# ('id', 'int', 'YES', '', None, '')

# %% [markdown]
# # inserting the records

# %%
import mysql.connector

conn = mysql.connector.connect(
    host='localhost',
    user='root',
    password='081908',
    database='pythondb'
)
mycursor = conn.cursor()

sql='insert into student (name,branch,id) values(%s,%s,%s)'

val=[('nilesh','cse','56'),('mike','it','78'),('tysin','me','80')]

mycursor.executemany(sql,val)
conn.commit()
print(mycursor.rowcount,'record inserted')
# Out:
# 3 record inserted

# %%
import tkinter as tk
root = tk.TK()
root.title('simple tkinter app')
root.geometry("200*100")

def say_hello():
    print('hello world')
hello_button=tk.Button(root,text='Click me', command=say_hello)
hello_button.pack(pady=20)

root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 2
#       1 import tkinter as tk
# ----> 2 root = tk.TK()
#       3 root.title('simple tkinter app')
#       4 root.geometry("200*100")
#
# AttributeError: module 'tkinter' has no attribute 'TK'

# %%
# !pip install tkinter
# Out:
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='pypi.org', port=443): Read timed out. (read timeout=15)")': /simple/tkinter/
# ERROR: Could not find a version that satisfies the requirement tkinter (from versions: none)
# ERROR: No matching distribution found for tkinter
