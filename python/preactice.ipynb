# %%
#1. What is the input() function in Python used for?
# -> is taking the input from the user

# %%
#2. How can you accept an integer as input from the user using input()?
n=input("enter a input")
b=int(n)
print(b)
print(type(b))
# Out:
# enter a input 15
# 15
# <class 'int'>

# %%
#3. How do you accept a float input from the user?
n=input("enter a input")
b=float(n)
print(b)
print(type(b))
# Out:
# enter a input 18
# 18.0
# <class 'float'>

# %%
#4. How can you take multiple space-separated values as input?
n=['name','nilesh','ram','kumar']
v=(" ".join(n))
print(v)
# Out:
# name nilesh ram kumar

# %%
#5.How do you check if a number entered by the user is positive, negative, or zero?
n=int(input("enter a number: "))
if n >0:
    print("is positive number :")
elif n<0:
    print("is negative number :")
else:
    print("is zero")
# Out:
# enter a number:  0
# is zero

# %%
#6.How do you convert user input to a list of integers?
n=1,5,7,8,6,7
l=list(n)
print(l)
print(type(l))
# Out:
# [1, 5, 7, 8, 6, 7]
# <class 'list'>

# %%
#7. How do you accept a string input and print it in uppercase?
s=("i am nilesh")

print(s.upper())
# Out:
# I AM NILESH

# %%
#8.Write a Python program that accepts a string and prints the number of vowels in it.
n=input("hello")
vowels=['a','e','i','o','u']
c=0
for char in n: #<-- in str use to char in str
    if char in vowels:
        c+=1
print(c)
# Out:
# hello nilesh
# 2

# %%
#9. Write a program that takes a number as input and checks if it is even or odd.
n=int(input("enter a number : "))
if n % 2==0:
    print("number is even",n)
else:
    print("odd number",n)
# Out:
# enter a number :  7
# odd number 7

# %%
# 10. How would you check if a string is a palindrome using input()?
n=input("enter a numer")
if n==n[::-1]:
    print("is polindrom")
else:
    print("is not polindrom")
# Out:
# enter a numer madam
# is polindrom

# %%
#11. Write a program that takes a number as input and prints its square.
n=int(input("enter a number"))
squre= n*n
print(squre)
# Out:
# enter a number 368736
# 135966237696

# %%
#12. Write a program that asks for a number and prints whether it is divisible by 3.
n=int(input("enter a number"))
if n % 3 == 0:
    print("this number is divide by 3",n)
else:
    print("this number is not diveide by the 3",n)
# Out:
# enter a number 9
# this number is divide by 3 9

# %%
#13. How would you check if a number is divisible by both 3 and 7?
for i in range(1,50):
    if i % 3 ==0 and i% 7==0:
        print("this divide by both",i)
    else:
        pass
# Out:
# this divide by both 21
# this divide by both 42

# %%
#14. How do you accept a list of comma-separated values as input?
n=(input("enter a number"))
l=list(n)
print(l)
print(type(l))
# Out:
# enter a number 19
# ['1', '9']
# <class 'list'>

# %%
#15. Write a Python program that takes two numbers as input and prints their product.
n=int(input("enter 1 number :"))
n1=int(input("enter 2 number :"))
product=n*n1
print(product)
# Out:
# enter 1 number : 8
# enter 2 number : 5
# 40

# %%
#16. Write a program that checks if the input number is a prime number
n = int(input("Enter a number: "))

if n > 1:  
    for i in range(2, n):
        if n % i == 0:
            print(n, "is not a prime number")
            break
    else:
        print(n, "is a prime number")
else:
    print(n, "is not a prime number")
# Out:
# Enter a number:  80
# 80 is not a prime number

# %%
#17. How can you accept a boolean value (True/False) from the user?
user_input = input("Enter True or False: ")
boolean_value = user_input == "True"
print(boolean_value)
# Out:
# Enter True or False:  true
# False

# %%
#18. Write a program that accepts a string and prints the reverse of that string
n=input("enter string")
c=n[::-1]
print(c)
# Out:
# enter string nilesh
# hselin

# %%
#19. Write a program that asks for a user's name and age and prints a message
name=input("enter a name")
age=int(input("enter a age"))
print(f'user name is {name} and age {age}')
# Out:
# enter a name nilesh
# enter a age 55
# user name is nilesh  and age 55

# %%
#20. Write a program to calculate the factorial of a number using input().
n=int(input("enter a number : "))
fact=1
for i in range(1,n+1):
    fact = fact *i
print(fact)
# Out:
# enter a number :  4
# 24

# %%
#21. How do you prevent a user from entering an empty stringn
n={'name':'nilesh','age':None}
n.values()
# Out:
# dict_values(['nilesh', None])

# %%
n=None
if n is None:
    print("is null")
else:
    print("is null")
# Out:
# is null

# %%
# 22. Write a program to check if the entered number is a perfect square
n = int(input("Enter a number: "))
root = int(n ** 0.5)
if root * root == n:
    print(n, "is a perfect square")
else:
    print(n, "is not a perfect square")
# Out:
# Enter a number:  24
# 24 is not a perfect square

# %%
import math as m
n=int(input("enter a number"))
root= m.isqrt(n)

if root * root ==n:
    print(n,"is the perfect squre")
else:
    print(n, "is not a perfect squre")
# Out:
# enter a number 100
# 100 is the perfect squre

# %%
#23. Write a program that asks for a year and determines if it's a leap year
n=int(input("enter a year"))
if n  % 400==0:
    print(n,"this is leap year")
elif n % 100==0:
    print(n,"is not a leap year")
elif n % 4==0:
    print(n,"this is leap year")
else:
    print("this is not leap year")
# Out:
# enter a year 2000
# 2000 this is leap year

# %%
# 24. How can you remove leading and trailing spaces from a string input?
n=("    nilesh          ".strip())
print(n)
# Out:
# nilesh

# %%
#25. How do you handle incorrect inputs when you expect an integer using input()?
n=input("enter input")
c=int(n)
print(c)
print(type(c))
# Out:
# enter input 5
# 5
# <class 'int'>

# %%
n=input("enter a number")
if n.isdigit():
   print("this is integer", int(n))
else:
    print("is not valif")
# Out:
# enter a number sgf
# is not valif

# %%
#26. Write a program that accepts a string and counts the occurrence of a particular
#character
n=input("enter a string")
char= input("enter a string")
count=n.count(char)
print(count)
# Out:
# enter a string i am nilesh
# enter a string nilesh
# 1

# %%
#27. How would you convert user input to lowercase using input()?
n=input("enter a input")
lower=n.lower()
print(lower)
# Out:
# enter a input NILESH
# nilesh

# %%
#28. Write a program that accepts a number and prints whether it is a multiple of 10.
n=int(input("enter a number"))
if n % 10 ==0:
    print(n,"this is multiple of 10")
else:
    print(n,"this is not multiple of 10")
# Out:
# enter a number 22
# 22 this is not multiple of 10

# %%
#29. How would you check if a string entered by the user contains only alphabets using
#input()?
n=input("enter a string")
alpha= n.isalpha()
print(alpha)
# Out:
# enter a string 165
# False

# %%
n=input("enter a string")
if n.isalpha():
    print(True)
else:
    print(False)
# Out:
# enter a string 36
# False

# %%
#30. Write a program to count the number of words in a sentence entered by the user
n=input("enter a words")
char=n.split()
b=len(char)
print(b,"word in sentence")
# Out:
# enter a words i am nilesh dn i am fasd
# 7 word in sentence

# %%
#31. How would you accept a date input from the user in Python?
def get_date():
    day = int(input("Enter day: "))
    month = int(input("Enter month: "))
    year = int(input("Enter year: "))
    return day, month, year

d, m, y = get_date()
print("You entered:", d, m, y)
# Out:
# Enter day:  09
# Enter month:  02
# Enter year:  2026
# You entered: 9 2 2026

# %%
from datetime import date

def get_date():
    day = int(input("Enter day: "))
    month = int(input("Enter month: "))
    year = int(input("Enter year: "))
    return date(year, month, day)  

print(get_date())
# Out:
# Enter day:  09
# Enter month:  02
# Enter year:  2026
# 2026-02-09

# %%
#32. Write a program that checks if the entered number is divisible by both 3 and 5.
n=int(input("enter a number"))
if n % 15==0:
    print("is divide by both")
else:
    print("is not")
# Out:
# enter a number 15
# is divide by both

# %%
#33. Write a program to swap the values of two variables using input().
a,b=1,2
a,b=b,a
print(a,b)
# Out:
# 2 1

# %%
a=int(input("enter a number"))
b=int(input("enter a number"))
a=a+b
b=a-b
a=a-b
print(a,b)
# Out:
# enter a number 1
# enter a number 2
# 2 1

# %%
a=int(input("enter a number"))
b=int(input("enter a number"))
a=a*b
b=a//b
a=a//b
print(a,b)
# Out:
# enter a number 1
# enter a number 2
# 2 1

# %%
a=int(input("enter a number"))
b=int(input("enter a number"))
a=a^b
b=a^b
a=a^b
print(a,b)
# Out:
# enter a number 1
# enter a number 2
# 2 1

# %%
#34. Write a program to take user input and print it without spaces between words.
i=input("enter a input")
i.replace(" ","")  # is using the replace
# Out:
# enter a input i am a student
# 'iamastudent'

# %%
#35. How do you validate if an entered input is a valid email address?
email=input("enter a email")
if email.endswith('@gmail.com'):
    print("is the valid gmail")
else:
    print("is invalid email")
# Out:
# enter a email xyz@gmail.com
# is the valid gmail

# %%
#36. Write a program that accepts a number and prints its cube.
n=int(input("enter a number"))
cube= n**3
print(f'{n} cube is= {cube}')
# Out:
# enter a number 5
# 5 cube is= 125

# %%
#37. How would you accept and store multiple names from the user?
names = []
n = int(input("How many names do you want to enter? "))

for i in range(n):
    name = input(f"Enter name {i+1}: ")
    names.append(name)

print("Stored names:", names)
names = names_input.split(",")  
print("Stored names:", names)
# Out:
# How many names do you want to enter?  3
# Enter name 1:  nilesh
# Enter name 2:  ram
# Enter name 3:  kamlesh
# Stored names: ['nilesh', 'ram', 'kamlesh']
# Stored names: ['nilesh ram kamlesh']

# %%
#38. How would you extract numbers from a string entered by the user?
text = input("enter input: ")
for word in text.split():
    if word.isdigit():
        print(word)
# Out:
# enter input:  my number is 123456
# 123456

# %%
#39. How do you find the maximum number from a list of integers entered by the user?
import numpy as np
n=np.array([1,2,5,7,8,9,55,8,77,00,11,15,3565,31000])
n.max()
# Out:
# np.int64(31000)

# %%
n=[1,2,3,4,5,22,11,44,88,77,33,100]
for i in n:
    if i == max(n):
        print(i,"is the max")
    elif i == min(n):
        print(i,"is the min")
# Out:
# 1 is the min
# 100 is the max

# %%
#40. How would you prompt the user for input until they enter a valid number?
while True:
    user_input = input("Enter a number: ")
    try:
        number = int(user_input)   
        print(f"Valid number entered: {number}")
        break  
    except ValueError:
        print("Invalid input. Please enter a valid number.")
# Out:
# Enter a number:  4
# Valid number entered: 4

# %%
#41. Write a program to check if the entered string has digits.
n=input("enter a string")

split= n.split()
digit= n.isdigit()
print("in this digit",digit)
# Out:
# enter a string nilesh 123
# in this digit False

# %%
#42. Write a program to check if the entered string has only whitespace characters.
s = input("Enter a string: ")

if s.isspace():
    print("The string contains only whitespace characters.")
elif s == "":
    print("The string is empty.")
else:
    print("The string contains non-whitespace characters.")
# Out:
# Enter a string:  "   "
# The string contains non-whitespace characters.

# %%
#43. Write a program to find the sum of all digits in a string entered by the user
s = input("Enter a string: ")

total = 0
for ch in s:
    if ch.isdigit():   
        total += int(ch)

print(f"sum of all is = {total} ")
# Out:
# Enter a string:  123456
# sum of all is = 21

# %%
#44. Write a program that accepts a number and prints its absolute value.

num = float(input("Enter a number: "))
absolute_value = abs(num)
print("The absolute value is:", absolute_value)
# Out:
# Enter a number:  -58
# The absolute value is: 58.0

# %%
#45. How would you check if a string entered by the user contains any uppercase
#letters?
n=input("enter a input")
if n == n.upper():
    print("this is upper case")
else:
    print("this not")
# Out:
# enter a input I AM NILESH
# this is upper case

# %%
#46. Write a program that converts Celsius to Fahrenheit.
c=int(input("enter celsius"))
ctof= (c*1.8) + 32
print(ctof)
# Out:
# enter celsius 30
# 86.0

# %%
#47. Write a program to find the average of a list of numbers entered by the user.

# %%
#48

# %%
#49

# %%
#50

# %% [markdown]
# # easy lavel quisten(1-20)

# %%
#1. Write a program to check if a number is even or odd.
n=int(input("enter a number"))
if n % 2==0:
  print("evan")
else:
  print("odd")
# Out:
# enter a number 5
# odd

# %%
#2. Check if a person is eligible to vote (age 18 or above).
age=int(input("enter a age"))
if age>=18:
  print("you are eligible for vote")
else:
  print("you are not eligible for vote")
# Out:
# enter a age 18
# you are eligible for vote

# %%
#3. Determine if a given year is a leap year or not.

n=int(input('enter a number'))
if n% 400==0:
  print('leap year',n)
elif n % 4==0:
  print("leap year",n)
else:
  print("not a leap yera")
# Out:
# enter a number 2000
# leap year 2000

# %%
#4. Check if a number is positive, negative, or zero.

n=int(input("enter anumber"))
if n >0:
  print("is positive number",n)
elif n< 0:
  print("is negative number")
elif n==0:
  print('is only zero')
else:
  print("invalid operation")
# Out:
# enter anumber 5
# is positive number 5

# %%
#5. Write a program to find the greatest of two numbers.
a=int(input("enter a number"))
b=int(input("enter a number"))

if a>b:
  print(f"{a} is grater then {b}")
elif b>a:
  print(f"{b} is grater then {a}")
elif a==b:
  print(f"{a} both are equal to {b}")
else:
  print("invalid operation")
# Out:
# enter a number 5
# enter a number 5
# 5 both are equal to 5

# %%
#6. Determine if a number is a multiple of 5.
n= int(input("enter a number"))
if n % 5==0:
  print(f"{n} is multiple of 5")
else:
  print("invalid operation")
# Out:
# enter a number 4
# invalid operation

# %%
# 7. Check if a character is a vowel or consonant.
vovwels=['a','e','i','o','u','A','E','I','O','U']
s=input('enter a charater')
if s in vovwels:
  print("is s vovwels")
else:
  print("is consonanat")
# Out:
# enter a charater a
# is s vovwels

# %%
#8. Determine if a person is eligible for a senior citizen discount (age 60+).
age=int(input("enter a age"))
if age>=60:
  print("you are eligible for senior citizen discount")
else:
  print('you are not eligible for senior citizen discount')
# Out:
# enter a age 60
# you are eligible for senior citizen discount

# %%
#9. Write a program to check if a number is a single-digit number.
n=int(input("enter a number"))
if n<10:
  print("is single digit number")
else:
  print('is not a single digit number')
# Out:
# enter a number 8
# is single digit number

# %%
#10.Print "Good Morning" if the time is before 12 PM, otherwise print "GoodAfternoon".
time=int(input('enter time')) 
if time<12:
  print("good morning")
else:
  print("good afternoon")
# Out:
# enter time 15
# good afternoon

# %%
#11.Check if a string is empty or not.
s=input('enter a string')
if s =="" :
  print("is the empty string")
else:
  print("is not a empty string")
# Out:
# enter a string
# is the empty string

# %%
#12. Verify if a number is a perfect square.
n=int(input('enter a number'))
squr= int(n**0.5)
if squr*squr==n:
  print(f'{n} this is perfect square')
else:
  print(f'{n} this is not perfect square')
# Out:
# enter a number 5
# 5 this is not perfect square

# %%
#13. Determine if a number is between 1 and 100
n=int(input("enter a number"))
if n>1 and n<100:
  print("this is between 1 and 100")
else:
  print("this is not between 1 and 100")
# Out:
# enter a number 65
# this is between 1 and 100

# %%
#14. Print "Weekend" if the day is Saturday or Sunday; otherwise, print "Weekday".
n=input('enter week day')
if n =='saturday' and n=='sunday':
    print("this is wekend")
else:
    print("this is week day")
# Out:
# enter week day saturday
# this is week day

# %%
#15. Find if a given number is exactly divisible by both 3 and 7.
n=int(input("enter a number"))
if n % 21 ==0:
    print(f"{n} this is devisible by 3 or 7")
else:
    print("this is not divisible by 3 or 7")
# Out:
# enter a number 42
# 42 this is devisible by 3 or 7

# %%
#16. Check if the sum of two numbers is greater than 100.
a=int(input("enter a number"))
b=int(input("enter a number"))
c=a+b
if c>100:
    print(f"{c} this is greater then 100")
else:
    print(f"{c} this is not grater then 100")
# Out:
# enter a number 150
# enter a number 3
# 153 this is greater then 100

# %%
#17. Write a program to find the minimum of two numbers.
a=int(input("enter a number"))
b=int(input("enter a number"))
if a<b:
    print(f'{a} is less then {b}')
else:
    print(f'{b} is less then {a}')
# Out:
# enter a number 1
# enter a number 2
# 1 is less then 2

# %%
#18. Check if a number is divisible by 2 but not by 3.
n= int(input("enter a number"))
if n % 2==0 and n % 3 !=0:
    print('this is divisible by 2 but not 3')
else:
    print("this is not divisible by 2 ")
# Out:
# enter a number 8
# this is divisible by 2 but not 3

# %%
#19. Determine if a given alphabet is uppercase or lowercase.
s=input('enter a string')
if s==s.upper():
    print("this is uppercase")
else:
    print("this is lower case")
# Out:
# enter a string NILESH
# this is uppercase

# %%
#20. Check if a triangle is valid given three side lengths (sum of any two sides mustbe greater than the third).
fangel=int(input('enter a 1 angle'))
sangel=int(input('enter a 2 angle'))
tangel=int(input('enter a 3 angle'))

perfect_triangel=(fangel+sangel+tangel)
if perfect_triangel ==180:
    print("this is a perfect triangel")
else:
    print("this is not a triangel")
# Out:
# enter a 1 angle 80
# enter a 2 angle 80
# enter a 3 angle 20
# this is a perfect triangel

# %% [markdown]
# # medium level(21-40)

# %%
#21. Find the largest of three numbers.
a=int(input("enter a number"))
b=int(input("enter a number"))
c=int(input("enter a number"))
if a>b and a>c:
    print(f"{a} is grater then {b} and {c}")
elif b>c and b>a:
    print(f"{b} is grater thenn {c} and {a}")
elif c>a and c>b:
    print(f"{c} is grater than {a} and {b}")
# Out:
# enter a number 15
# enter a number 50
# enter a number 16
# 50 is grater thenn 16 and 15

# %%
#22. Determine if a number is a prime number.
n= int(input("Enter a number: "))

if n > 1:  
    for i in range(2, n):
        if n % i == 0:
            print(n, "is not a prime number")
            break
    else:
        print(n, "is a prime number")
else:
    print(n, "is not a prime number")
# Out:
# Enter a number:  7
# 7 is a prime number

# %%
#23. Check if a person is eligible for a driving license (age 18+, passed the drivingtest)

age=int(input("enter a age"))
test=input('enter the result of you driving test')
if age>=18 and test=='pass':
    print("this is eligible for the driveing license")
else:
    print("this is not approve to get the driving license")
# Out:
# enter a age 18
# enter the result of you driving test pass
# this is eligible for the driveing license

# %%
#24. Write a program to determine whether a triangle is equilateral, isosceles, orscalene.

a = int(input("Enter side a: "))
b = int(input("Enter side b: "))
c = int(input("Enter side c: "))

if a == b == c:
    print("Equilateral Triangle")
elif a == b or b == c or a == c:
    print("Isosceles Triangle")
else:
    print("Scalene Triangle")
# Out:
# Enter side a:  80
# Enter side b:  90
# Enter side c:  10
# Scalene Triangle

# %%
#25. Determine if a student passes or fails based on a passing mark of 40.
marks=int(input("enter a marks"))
if marks >= 40 and marks <101:
    print('this is pass')
else:
    print('this fail')
# Out:
# enter a marks 80
# this is pass

# %%
#26. Check if a number is a palindrome (same forward and backward).
n=input('enter input')
if n==n[::-1]:
    print("this is polindrom")
else:
    ("this is not a polindrom")
# Out:
# enter input madam
# this is polindrom

# %%
#27. Calculate the electricity bill based on consumption: ₹5 per unit for the first 100units, ₹10 per unit for the next 200, ₹15 per unit for anything above 300 units.
con=int(input('enter a counsumptions'))
if con<100:
    total=con*5
    print(f"total bill is = {total}")
elif con>100 and con<200:
    total=con*10
    print(f"total bill is= {total}")
elif
