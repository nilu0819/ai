# %% [markdown]
# # evan number

# %%
x=4 
r=x % 2
if r==0:
    print("even number ")
# Out:
# even number

# %%
n=5
r=n%2
if r==0:
    print('evan')

# %%
a=5
b=a%2
if b==0:
    print("even bumber")
print("odd")
# Out:
# odd

# %%
x=10 
r =x%2
if r==0:
    print("even number")
    if x>5:
        print("grater number")
else:
    prin("odd number")
# Out:
# even number
# grater number

# %%
x=4
r=x%2
if r==0:
    print("even number")
    if x>5:
        print('greater number')
else:
    print("odd number")
# Out:
# even number

# %%
r=1
x=r%2
if x==0:
    print("even number")
    if x>5:
        print("grater number")
    else:
        print("smaller number")
else:
    print("odd numner")
# Out:
# odd numner

# %%
x=2
if x==1:
    print("one")
if x==2:
    print("two")
if x==3:
    print("three")
# Out:
# two

# %%
x=1
if x==1:
    print("one")
elif x==2:
    print("two")
elif x==3:
    print("three")
# Out:
# one

# %%
x=3
if x==1:
    print("one")
elif x==2:
    print("two")
elif x==3:
    print("three")
else:
    print("number out range")
# Out:
# three

# %%
i=1
while i<=5:
    print("nilesh",i)
    i+=1
# Out:
# nilesh 1
# nilesh 2
# nilesh 3
# nilesh 4
# nilesh 5

# %%
i =5
while i>=1:
    print("data science",i)
    i-=1
# Out:
# data science 5
# data science 4
# data science 3
# data science 2
# data science 1

# %%
i=1
while i <=5:
    print("data science")
    j=1
    while j<=4:
        print("technology")
        j+=1
    i+=1
    print()
# Out:
# data science
# technology
# technology
# technology
# technology
#
# data science
# technology
# technology
# technology
# technology
#
# data science
# technology
# technology
# technology
# technology
#
# data science
# technology
# technology
# technology
# technology
#
# data science
# technology
# technology
# technology
# technology

# %%
i=1
while i<=5:
    print("data science",end=' ')
    j=1
    while j<=4:
        print("technology",end=' ')
        j+=1
    i+=1
    print()
# Out:
# data science technology technology technology technology
# data science technology technology technology technology
# data science technology technology technology technology
# data science technology technology technology technology
# data science technology technology technology technology

# %%
i =1
while i<=2:
    j=0
    while j<=2:
        print(i*j,end=' ')
        j+=1
    print()
    i+=1
# Out:
# 0 1 2
# 0 2 4

# %%
i=1
while i <=4:
    j=0
    while j<=4:
        print(i*j, end=' ')
        j+=1
    print()
    i+=1
# Out:
# 0 1 2 3 4
# 0 2 4 6 8
# 0 3 6 9 12
# 0 4 8 12 16

# %%
u=int(input('enter input'))
# Out:
# enter input niae
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 u=int(input('enter input'))
#
# ValueError: invalid literal for int() with base 10: 'niae'

# %%
u=float(input("enter a numer"))
print(u)
# Out:
# enter a numer 4
# 4.0

# %%
print('nilesh','ram','rajesh',sep=' ')
# Out:
# nilesh ram rajesh

# %%
n=int(input("enter a numer"))
if n >0:
    print("is positive value")
elif n < 0:
    print("is negative number")
elif n==0:
    print("is zero number")
# Out:
# enter a numer 0
# is zero number

# %%
u=input("enter a nnumber")
u
list(u)
# Out:
# enter a nnumber 687
# ['6', '8', '7']

# %%
s=('nilesh')
s.upper()
# Out:
# 'NILESH'

# %%
n=input("enter inpu")
v=('aeiou')
c=0
i=0
while i < v:
    if n  in v:
        c+=1
    i+=1
print(c)
# Out:
# enter inpu nkluh
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 5
#       3 c=0
#       4 i=0
# ----> 5 while i < v:
#       6     if n  in v:
#       7         c+=1
#
# TypeError: '<' not supported between instances of 'int' and 'str'

# %%
x=10
if  x%2==0:
    print("even number")
else:
    print("odd number")
# Out:
# even number

# %%
x=5
if x % 2==0:
    print("even number ")
else:
    print("odd number")
# Out:
# odd number

# %%
age=18
if age >=18:
    print("eligible foe vate")
else:
    print("not aligible")
# Out:
# eligible foe vate

# %%
age =5
if age>=18:
    print("eligible for vate")
else:
    print("not eligiblr")
# Out:
# not eligiblr

# %%
pas='1231897uh'
if len(pas) >=8:
    print("strong paass")
else:
    print("week pass")
# Out:
# strong paass

# %%
from PIL import Image

# %%
image=Image.open(r'D:\Pictures\Screenshots\Screenshot 2025-08-30 165901.png')

# %%
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1024x614>

# %%
#trafic signals
lights=input("enter a input")

if lights == 'red':
    print("stop")
elif lights == 'yellow':
    print("ready for go")
elif lights == 'green':
    print("go")
else:
    print("invalid ")
# Out:
# enter a input yellow
# ready for go

# %%
age=int(input("enter a age"))

if age<13:
    print("chiled")
elif age< 20:
    print("teen")
elif age <60:
    print("adult")
else:
    print("senior citizen")
# Out:
# enter a age 68
# senior citizen

# %%
name='nilesh'
pas='nilu'
if name=='nilesh':
    if pas=='nilu':
        print("login sucess")
# Out:
# login sucess

# %%
name='nilesh'
pas='nil'
if name=='nilesh':
    if pas=='nilu':
        print("login sucess")
    else:
        print("login failed")
# Out:
# login failed

# %%
age=397
salary=60000
if age >20 and age < 100:
    if salary > 40000:
        print("eligible for loan")
    else:
        print("low salary")
else:
    print("age is not eligible")
# Out:
# age is not eligible

# %%
c=0
while c <3:
    c+=1
    print('nilesh')
# Out:
# nilesh
# nilesh
# nilesh

# %%
count=0
while count <5:
    print(count)
    count+=1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
i=0
n='nilesh ram'
while len(n) >i:
    if n[i] =='e' or n[i]=='h':
        i+=1
        continue
    print(n[i])
    i+=1
# Out:
# n
# i
# l
# s
#
# r
# a
# m

# %%
i=0
n='nilesh'
while len(n) > i:
    if n[i] == 'e':
        i+=1
        break
    print(n[i])
    i+=1
# Out:
# n
# i
# l

# %%
n='nilesh ram'
i=0
while len(n) > i:
    i+=1
    pass
print("value of i",i)
# Out:
# value of i 10

# %%
i=0
while i<4:
    i+=1
    print(i)
else:
    print("no  break\n")

i=0
while i <4:
    i+=1
    print(i)
    break
else:
    print("no break")
# Out:
# 1
# 2
# 3
# 4
# no  break
#
# 1

# %% [markdown]
# # for loop
