# %%
num1 = 20
num2 = 30
add = num1 + num2
print("the addition of {} and {} is = {}".format(num1,num2,add))
# Out:
# the addition of 20 and 30 is = 50

# %%
name = "nilesh"
age= 22
city = "surat"
print("my name is  {} and my age is {} and i live in {}".format(name,age,city))
# Out:
# my name is  nilesh and my age is 22 and i live in surat

# %%
marks = int(input("enter a mark you can got in exam : "))

 

if marks >=90 and marks<=100:
    print("A+",marks)
elif marks >=75 and marks <90:
    print("B+",marks)
elif marks >=60 and marks < 75:
    print("C+",marks)
elif marks >=35 and marks < 60 :
    print('D+',marks)
elif marks <35:
    print(" you are fail")
else:
    print("you enter the wrong number give inbeetwen in 0 to 100")
# Out:
# enter a mark you can got in exam :  56
# D+ 56

# %%
student={'nilesh':80,'akash':50,'harsh':33,'vikash':45}
student
# Out:
# {'nilesh': 80, 'akash': 50, 'harsh': 33, 'vikash': 45}

# %%
student.values()
# Out:
# dict_values([80, 50, 33, 45])

# %%
len(student)
# Out:
# 4

# %%
marks = {"Alice": 85, "Bob": 90, "Charlie": 78}
marks
# Out:
# {'Alice': 85, 'Bob': 90, 'Charlie': 78}

# %%
marks['nilesh']=92
marks
# Out:
# {'Alice': 85, 'Bob': 90, 'Charlie': 78, 'nilesh': 92}

# %%
marks['nilesh']=75
marks
# Out:
# {'Alice': 'nilesh', 'Bob': 90, 'Charlie': 78, 'nilesh': 75, 85: 75}

# %%
len(marks
   )
# Out:
# 5

# %%
marks.pop
marks
# Out:
# {'Alice': 'nilesh', 'Bob': 90, 'Charlie': 78, 'nilesh': 75, 85: 75}

# %%
marks1={'name':'nilesh','marks':50,'age':22}
marks1
# Out:
# {'name': 'nilesh', 'marks': 50, 'age': 22}

# %%
marks1['name']='akash'
marks1['marks']=100
marks1['age']=30
marks1
# Out:
# {'name': 'akash', 'marks': 100, 'age': 30}

# %%
sentence = "python is fun and python is powerful"
sentence.count('python')
# Out:
# 2

# %%
sentence.count('is')
# Out:
# 2

# %%
sentence.count('fun')
# Out:
# 1

# %%
sentence.count('and')
# Out:
# 1

# %%
students = {"Alice": 85,"Bob": 92,"Charlie": 78,"Diana": 90}
students
type(students)
# Out:
# dict

# %%
num = [1,2,5,[15,25,30],62,90]
type(num)
# Out:
# list

# %%
num[3][2]
# Out:
# 30

# %%
#l = 3
c= [10,20,30,40,50,60]
c
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
#print index 1 to 4
c[1:4]
# Out:
# [20, 30, 40]

# %%
#print the first 3 element
c[:3]
# Out:
# [10, 20, 30]

# %%
#print the lement index 2 to end
c[1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[133], line 2
#       1 #print the lement index 2 to end
# ----> 2 c[1]
#
# IndexError: list index out of range

# %%
import numpy as np

# %%
n=[6,5,8,7,9,6,3,2,1,4,7,8,2,4]
total=0
for i in n:
    total=total+i
print(total/len(n))
# Out:
# 5.142857142857143

# %%
import numpy as np
a=np.array([6,5,8,7,9,6,3,2,1,4,7,8,2,4])
np.mean(a)
# Out:
# np.float64(5.142857142857143)

# %%
a=("666666")
b=("4444")
c=("&")
print(a+c+b)
# Out:
# 666666&4444

# %%
r=5
for i in range(1,r+1):
    for j in range(1,i+1):
        print("*",end=' ')
    print()
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *

# %%
for i in range(6,0,-):
    for j in range(1,i+1):
        print("*",end=' ')
    print()
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *

# %%
import pandas as pd

# %%
df=pd.read_excel(r'C:\Users\niles\Downloads\data.xlsx')

# %%
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
id(df)
# Out:
# 2046666804928

# %%
df.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 5

# %%
df.isnull()
# Out:
#      CountryName  CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0          False        False      False          False        False
# 1          False        False      False          False        False
# 2          False        False      False          False        False
# 3          False        False      False          False        False
# 4          False        False      False          False        False
# ..           ...          ...        ...            ...          ...
# 190        False        False      False          False        False
# 191        False        False      False          False        False
# 192        False        False      False          False        False
# 193        False        False      False          False        False
# 194        False        False      False          False        False
#
# [195 rows x 5 columns]

# %%
df.isna()
# Out:
#      CountryName  CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0          False        False      False          False        False
# 1          False        False      False          False        False
# 2          False        False      False          False        False
# 3          False        False      False          False        False
# 4          False        False      False          False        False
# ..           ...          ...        ...            ...          ...
# 190        False        False      False          False        False
# 191        False        False      False          False        False
# 192        False        False      False          False        False
# 193        False        False      False          False        False
# 194        False        False      False          False        False
#
# [195 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# CountryName      0
# CountryCode      0
# BirthRate        0
# InternetUsers    0
# IncomeGroup      0
# dtype: int64

# %%
df.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
df.tail()
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 190       Yemen, Rep.         YEM     32.947           20.0
# 191      South Africa         ZAF     20.850           46.5
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
# 194          Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
df.nunique()
# Out:
# CountryName      195
# CountryCode      195
# BirthRate        177
# InternetUsers    181
# IncomeGroup        4
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CountryName    195 non-null    object
#  1   CountryCode    195 non-null    object
#  2   BirthRate      195 non-null    float64
#  3   InternetUsers  195 non-null    float64
#  4   IncomeGroup    195 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
df.describe()
# Out:
#         BirthRate  InternetUsers
# count  195.000000     195.000000
# mean    21.469928      42.076471
# std     10.605467      29.030788
# min      7.900000       0.900000
# 25%     12.120500      14.520000
# 50%     19.680000      41.000000
# 75%     29.759500      66.225000
# max     49.661000      96.546800

# %%
df[1:3]
# Out:
#    CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 1  Afghanistan         AFG     35.253            5.9           Low income
# 2       Angola         AGO     45.985           19.1  Upper middle income

# %%
df[-2:-1]
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 193      Zambia         ZMB     40.471           15.4  Lower middle income

# %%
df.CountryName
# Out:
# 0                     Aruba
# 1               Afghanistan
# 2                    Angola
# 3                   Albania
# 4      United Arab Emirates
#                ...
# 190             Yemen, Rep.
# 191            South Africa
# 192        Congo, Dem. Rep.
# 193                  Zambia
# 194                Zimbabwe
# Name: CountryName, Length: 195, dtype: object

# %%
df.CountryCode
# Out:
# 0      ABW
# 1      AFG
# 2      AGO
# 3      ALB
# 4      ARE
#       ...
# 190    YEM
# 191    ZAF
# 192    COD
# 193    ZMB
# 194    ZWE
# Name: CountryCode, Length: 195, dtype: object

# %%
df[["CountryName","CountryCode","IncomeGroup"]]
# Out:
#               CountryName CountryCode          IncomeGroup
# 0                   Aruba         ABW          High income
# 1             Afghanistan         AFG           Low income
# 2                  Angola         AGO  Upper middle income
# 3                 Albania         ALB  Upper middle income
# 4    United Arab Emirates         ARE          High income
# ..                    ...         ...                  ...
# 190           Yemen, Rep.         YEM  Lower middle income
# 191          South Africa         ZAF  Upper middle income
# 192      Congo, Dem. Rep.         COD           Low income
# 193                Zambia         ZMB  Lower middle income
# 194              Zimbabwe         ZWE           Low income
#
# [195 rows x 3 columns]

# %%
df_cat=df[["CountryName","CountryCode","IncomeGroup"]]
df_cat
# Out:
#               CountryName CountryCode          IncomeGroup
# 0                   Aruba         ABW          High income
# 1             Afghanistan         AFG           Low income
# 2                  Angola         AGO  Upper middle income
# 3                 Albania         ALB  Upper middle income
# 4    United Arab Emirates         ARE          High income
# ..                    ...         ...                  ...
# 190           Yemen, Rep.         YEM  Lower middle income
# 191          South Africa         ZAF  Upper middle income
# 192      Congo, Dem. Rep.         COD           Low income
# 193                Zambia         ZMB  Lower middle income
# 194              Zimbabwe         ZWE           Low income
#
# [195 rows x 3 columns]

# %%
print(len(df.columns))
print(len(df_cat.columns))
# Out:
# 5
# 3

# %%
print((df_cat.columns))
# Out:
# Index(['CountryName', 'CountryCode', 'IncomeGroup'], dtype='object')

# %%
df_cat.describe
# Out:
# <bound method NDFrame.describe of               CountryName CountryCode          IncomeGroup
# 0                   Aruba         ABW          High income
# 1             Afghanistan         AFG           Low income
# 2                  Angola         AGO  Upper middle income
# 3                 Albania         ALB  Upper middle income
# 4    United Arab Emirates         ARE          High income
# ..                    ...         ...                  ...
# 190           Yemen, Rep.         YEM  Lower middle income
# 191          South Africa         ZAF  Upper middle income
# 192      Congo, Dem. Rep.         COD           Low income
# 193                Zambia         ZMB  Lower middle income
# 194              Zimbabwe         ZWE           Low income
#
# [195 rows x 3 columns]>

# %%
df_num=df[["BirthRate","InternetUsers"]]

# %%
df_num
# Out:
#      BirthRate  InternetUsers
# 0       10.244           78.9
# 1       35.253            5.9
# 2       45.985           19.1
# 3       12.877           57.2
# 4       11.044           88.0
# ..         ...            ...
# 190     32.947           20.0
# 191     20.850           46.5
# 192     42.394            2.2
# 193     40.471           15.4
# 194     35.715           18.5
#
# [195 rows x 2 columns]

# %%
df_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   BirthRate      195 non-null    float64
#  1   InternetUsers  195 non-null    float64
# dtypes: float64(2)
# memory usage: 3.2 KB

# %%
df.describe().transpose()
# Out:
#                count       mean        std  min      25%    50%      75%  \
# BirthRate      195.0  21.469928  10.605467  7.9  12.1205  19.68  29.7595
# InternetUsers  195.0  42.076471  29.030788  0.9  14.5200  41.00  66.2250
#
#                    max
# BirthRate      49.6610
# InternetUsers  96.5468

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.3.3'

# %%
df=pd.read_excel(r'C:\Users\niles\Downloads\data.xlsx')

# %%
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
df.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
df.tail()
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 190       Yemen, Rep.         YEM     32.947           20.0
# 191      South Africa         ZAF     20.850           46.5
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
# 194          Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
df.describe()
# Out:
#         BirthRate  InternetUsers
# count  195.000000     195.000000
# mean    21.469928      42.076471
# std     10.605467      29.030788
# min      7.900000       0.900000
# 25%     12.120500      14.520000
# 50%     19.680000      41.000000
# 75%     29.759500      66.225000
# max     49.661000      96.546800

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CountryName    195 non-null    object
#  1   CountryCode    195 non-null    object
#  2   BirthRate      195 non-null    float64
#  3   InternetUsers  195 non-null    float64
#  4   IncomeGroup    195 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
df['CountryName']
# Out:
# 0                     Aruba
# 1               Afghanistan
# 2                    Angola
# 3                   Albania
# 4      United Arab Emirates
#                ...
# 190             Yemen, Rep.
# 191            South Africa
# 192        Congo, Dem. Rep.
# 193                  Zambia
# 194                Zimbabwe
# Name: CountryName, Length: 195, dtype: object

# %%
df[['CountryName','InternetUsers']]
# Out:
#               CountryName  InternetUsers
# 0                   Aruba           78.9
# 1             Afghanistan            5.9
# 2                  Angola           19.1
# 3                 Albania           57.2
# 4    United Arab Emirates           88.0
# ..                    ...            ...
# 190           Yemen, Rep.           20.0
# 191          South Africa           46.5
# 192      Congo, Dem. Rep.            2.2
# 193                Zambia           15.4
# 194              Zimbabwe           18.5
#
# [195 rows x 2 columns]

# %%
df=df['InternetUsers'] >10

# %%
df.sum()
# Out:
# np.int64(157)

# %%
df.isnull
# Out:
# <bound method Series.isnull of 0       True
# 1      False
# 2       True
# 3       True
# 4       True
#        ...
# 190     True
# 191     True
# 192    False
# 193     True
# 194     True
# Name: InternetUsers, Length: 195, dtype: bool>

# %%
df.isnull().sum()
# Out:
# np.int64(0)

# %%
df['CountryName']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 df['CountryName']
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:1133, in Series.__getitem__(self, key)
#    1130     return self._values[key]
#    1132 elif key_is_scalar:
# -> 1133     return self._get_value(key)
#    1135 # Convert generator to list before going through hashable part
#    1136 # (We will iterate through the generator there to check for slices)
#    1137 if is_iterator(key):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:1249, in Series._get_value(self, label, takeable)
#    1246     return self._values[label]
#    1248 # Similar to Index.get_value, but we do not fall back to positional
# -> 1249 loc = self.index.get_loc(label)
#    1251 if is_integer(loc):
#    1252     return self._values[loc]
#
# ...

# %%
import pandas as pd

# %%
emp=pd.read_excel(r"C:\Users\niles\OneDrive\Documents\Desktop\dataset\Rawdata.xlsx")

# %%
emp
# Out:
#      Name          Domain       Age   Location   Salary      Exp
# 0    Mike   Datascience#$  34 years     Mumbai   5^00#0       2+
# 1  Teddy^         Testing    45' yr  Bangalore  10%%000       <3
# 2   Uma#r  Dataanalyst^^#       NaN        NaN  1$5%000   4> yrs
# 3    Jane     Ana^^lytics       NaN   Hyderbad   2000^0      NaN
# 4  Uttam*      Statistics     67-yr        NaN   30000-  5+ year
# 5     Kim             NLP      55yr      Delhi  6000^$0      10+

# %%
emp['Name']
# Out:
# 0      Mike
# 1    Teddy^
# 2     Uma#r
# 3      Jane
# 4    Uttam*
# 5       Kim
# Name: Name, dtype: object

# %%
emp['Name'] = emp['Name'].str.replace(r'\W','',regex=True)

# %%
emp['Name']
# Out:
# 0     Mike
# 1    Teddy
# 2     Umar
# 3     Jane
# 4    Uttam
# 5      Kim
# Name: Name, dtype: object

# %%
emp
# Out:
#     Name          Domain       Age   Location   Salary      Exp   name
# 0   Mike   Datascience#$  34 years     Mumbai   5^00#0       2+   Mike
# 1  Teddy         Testing    45' yr  Bangalore  10%%000       <3  Teddy
# 2   Umar  Dataanalyst^^#       NaN        NaN  1$5%000   4> yrs   Umar
# 3   Jane     Ana^^lytics       NaN   Hyderbad   2000^0      NaN   Jane
# 4  Uttam      Statistics     67-yr        NaN   30000-  5+ year  Uttam
# 5    Kim             NLP      55yr      Delhi  6000^$0      10+    Kim

# %%
emp['Domain']=emp['Domain'].str.replace(r'\W','',regex=True)

# %%
emp['Domain']
# Out:
# 0    Datascience
# 1        Testing
# 2    Dataanalyst
# 3      Analytics
# 4     Statistics
# 5            NLP
# Name: Domain, dtype: object

# %%
emp
# Out:
#     Name       Domain       Age   Location   Salary      Exp   name
# 0   Mike  Datascience  34 years     Mumbai   5^00#0       2+   Mike
# 1  Teddy      Testing    45' yr  Bangalore  10%%000       <3  Teddy
# 2   Umar  Dataanalyst       NaN        NaN  1$5%000   4> yrs   Umar
# 3   Jane    Analytics       NaN   Hyderbad   2000^0      NaN   Jane
# 4  Uttam   Statistics     67-yr        NaN   30000-  5+ year  Uttam
# 5    Kim          NLP      55yr      Delhi  6000^$0      10+    Kim

# %%
emp['Age'] = emp['Age'].str.extract('(\d+)')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\niles\AppData\Local\Temp\ipykernel_13736\3236405637.py:1: SyntaxWarning: invalid escape sequence '\d'
#   emp['Age'] = emp['Age'].str.extract('(\d+)')

# %%
emp['Age']
# Out:
# 0     34
# 1     45
# 2    NaN
# 3    NaN
# 4     67
# 5     55
# Name: Age, dtype: object

# %%
emp['Salary'] = emp['Salary'].str.extract('(\d+)')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\niles\AppData\Local\Temp\ipykernel_13736\354079153.py:1: SyntaxWarning: invalid escape sequence '\d'
#   emp['Salary'] = emp['Salary'].str.extract('(\d+)')

# %%
emp['Salary']
# Out:
# 0        5
# 1       10
# 2        1
# 3     2000
# 4    30000
# 5     6000
# Name: Salary, dtype: object

# %%
emp['Exp'] = emp['Exp'].str.extract('(\d+)')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\niles\AppData\Local\Temp\ipykernel_13736\3836251810.py:1: SyntaxWarning: invalid escape sequence '\d'
#   emp['Exp'] = emp['Exp'].str.extract('(\d+)')

# %%
emp['Exp']
# Out:
# 0      2
# 1      3
# 2      4
# 3    NaN
# 4      5
# 5     10
# Name: Exp, dtype: object

# %%
emp
# Out:
#     Name       Domain  Age   Location Salary  Exp   name
# 0   Mike  Datascience   34     Mumbai      5    2   Mike
# 1  Teddy      Testing   45  Bangalore     10    3  Teddy
# 2   Umar  Dataanalyst  NaN        NaN      1    4   Umar
# 3   Jane    Analytics  NaN   Hyderbad   2000  NaN   Jane
# 4  Uttam   Statistics   67        NaN  30000    5  Uttam
# 5    Kim          NLP   55      Delhi   6000   10    Kim

# %%
emp.isnull().sum()
# Out:
# Name        0
# Domain      0
# Age         2
# Location    2
# Salary      0
# Exp         1
# name        0
# dtype: int64

# %%
import numpy as np

# %%
clean_data=emp.copy()

# %%
clean_data
# Out:
#     Name       Domain  Age   Location Salary  Exp   name
# 0   Mike  Datascience   34     Mumbai      5    2   Mike
# 1  Teddy      Testing   45  Bangalore     10    3  Teddy
# 2   Umar  Dataanalyst  NaN        NaN      1    4   Umar
# 3   Jane    Analytics  NaN   Hyderbad   2000  NaN   Jane
# 4  Uttam   Statistics   67        NaN  30000    5  Uttam
# 5    Kim          NLP   55      Delhi   6000   10    Kim

# %%
clean_data['Age']=clean_data['Age'].fillna(np.mean(pd.to_numeric(clean_data['Age'])))

# %%
clean_data
# Out:
#     Name       Domain    Age   Location Salary  Exp   name
# 0   Mike  Datascience     34     Mumbai      5    2   Mike
# 1  Teddy      Testing     45  Bangalore     10    3  Teddy
# 2   Umar  Dataanalyst  50.25  Bangalore      1    4   Umar
# 3   Jane    Analytics  50.25   Hyderbad   2000  NaN   Jane
# 4  Uttam   Statistics     67  Bangalore  30000    5  Uttam
# 5    Kim          NLP     55      Delhi   6000   10    Kim

# %%
clean_data['Age']
# Out:
# 0       34
# 1       45
# 2    50.25
# 3    50.25
# 4       67
# 5       55
# Name: Age, dtype: object

# %%
clean_data['Exp']=clean_data['Exp'].fillna(np.mean(pd.to_numeric(clean_data['Exp'])))

# %%
clean_data['Exp']
# Out:
# 0      2
# 1      3
# 2      4
# 3    4.8
# 4      5
# 5     10
# Name: Exp, dtype: object

# %%
clean_data['Location']=clean_data['Location'].fillna(clean_data['Location'].mode()[0])

# %%
clean_data['Location']
# Out:
# 0       Mumbai
# 1    Bangalore
# 2    Bangalore
# 3     Hyderbad
# 4    Bangalore
# 5        Delhi
# Name: Location, dtype: object

# %%
clean_data
# Out:
#     Name       Domain    Age   Location Salary  Exp   name
# 0   Mike  Datascience     34     Mumbai      5    2   Mike
# 1  Teddy      Testing     45  Bangalore     10    3  Teddy
# 2   Umar  Dataanalyst  50.25  Bangalore      1    4   Umar
# 3   Jane    Analytics  50.25   Hyderbad   2000  4.8   Jane
# 4  Uttam   Statistics     67  Bangalore  30000    5  Uttam
# 5    Kim          NLP     55      Delhi   6000   10    Kim

# %%
pwd
# Out:
# 'C:\\Users\\niles'

# %%
clean_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      6 non-null      object
#  1   Domain    6 non-null      object
#  2   Age       6 non-null      object
#  3   Location  6 non-null      object
#  4   Salary    6 non-null      object
#  5   Exp       6 non-null      object
#  6   name      6 non-null      object
# dtypes: object(7)
# memory usage: 468.0+ bytes

# %%
clean_data['Name']=clean_data['Name'].astype('category')
clean_data['Domain']=clean_data['Domain'].astype('category')
clean_data['Age']=clean_data['Age'].astype(int)
clean_data['Location']=clean_data['Location'].astype('category')
clean_data['Salary']=clean_data['Salary'].astype(int)
clean_data['Exp']=clean_data['Exp'].astype(int)

# %%
clean_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      6 non-null      category
#  1   Domain    6 non-null      category
#  2   Age       6 non-null      int64
#  3   Location  6 non-null      category
#  4   Salary    6 non-null      int64
#  5   Exp       6 non-null      int64
#  6   name      6 non-null      object
# dtypes: category(3), int64(3), object(1)
# memory usage: 986.0+ bytes

# %%
clean_data
# Out:
#     Name       Domain  Age   Location  Salary  Exp   name
# 0   Mike  Datascience   34     Mumbai       5    2   Mike
# 1  Teddy      Testing   45  Bangalore      10    3  Teddy
# 2   Umar  Dataanalyst   50  Bangalore       1    4   Umar
# 3   Jane    Analytics   50   Hyderbad    2000    4   Jane
# 4  Uttam   Statistics   67  Bangalore   30000    5  Uttam
# 5    Kim          NLP   55      Delhi    6000   10    Kim

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.lineplot(data=clean_data,x='Domain',y='Salary')
# Out:
# <Axes: xlabel='Domain', ylabel='Salary'>

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
vis1=sns.distplot(clean_data['Salary'])

# %%
vis2=plt.hist(clean_data['Salary'])

# %%
vis3=sns.lmplot(data=clean_data,x='Exp',y='Salary')

# %%
import mysql.
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import mysql.connector
#
# ModuleNotFoundError: No module named 'mysql'
