# %% [markdown]
# # read the video

# %%
import cv2

cap=cv2.VideoCapture(0)

width = cap.get(cv2.CAP_PROP_FRAME_WIDTH)
height = cap.get(cv2.CAP_PROP_FRAME_HEIGHT)

while True:
    ret,frame = cap.read()
    if not ret:
        break
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    
    cv2.imshow('frame',gray)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import cv2
#       3 cap=cv2.VideoCapture(0)
#       5 width = cap.get(cv2.CAP_PROP_FRAME_WIDTH)
#
# ModuleNotFoundError: No module named 'cv2'

# %% [markdown]
# # Assistant
# This error occurs because OpenCV is trying to convert an empty frame to grayscale. The `cap.read()` function is not successfully capturing a frame, which could be due to issues with your camera or its connection.
#
# The error is happening at this line:

# %%
gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#
# NameError: name 'cv2' is not defined

# %% [markdown]
# The assertion `!_src.empty()` is failing, which means `frame` is empty.
#
# Would you like me to provide the corrected code?

# %%
import cv2

cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Convert to grayscale
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Show both original and grayscale
    cv2.imshow('Original', frame)
    cv2.imshow('Gray', gray)

    # Press 'q' to quit
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
import cv2

cap = cv2.VideoCapture(0)  # Try camera index 0

# Check if the camera opened successfully
if not cap.isOpened():
    print("Error: Could not open camera.")
    exit()

width = cap.get(cv2.CAP_PROP_FRAME_WIDTH)
height = cap.get(cv2.CAP_PROP_FRAME_HEIGHT)

while True:
    ret, frame = cap.read()
    
    # Check if frame was successfully read
    if not ret:
        print("Error: Can't receive frame (stream end?). Exiting ...")
        break
        
    # Only convert to grayscale if we have a valid frame
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    
    cv2.imshow('frame', gray)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
        
cap.release()
cv2.destroyAllWindows()

# %%
cap=cv2.VideoCapture(0)
