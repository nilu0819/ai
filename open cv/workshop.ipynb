# %% [markdown]
# # introduction to opencv & image processing

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2
print(cv2.__version__)
# Out:
# 4.13.0

# %%
import cv2
import numpy as np

# Create a blank image
img = np.zeros((200, 200, 3), dtype=np.uint8)
cv2.putText(img, "Hello OpenCV", (10, 100), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255,255,255), 2)

cv2.imshow("Test", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.imread(r'C:\Users\niles\OneDrive\Pictures\134118367428608576.jpg')
img
# Out:
# array([[[253, 232, 194],
#         [252, 231, 193],
#         [251, 230, 192],
#         ...,
#         [253, 234, 191],
#         [249, 232, 189],
#         [252, 235, 192]],
#
#        [[253, 230, 192],
#         [253, 230, 192],
#         [253, 230, 192],
#         ...,
#         [250, 231, 188],
#         [247, 230, 187],
#         [250, 233, 190]],
#
#        [[255, 229, 192],
#         [255, 229, 192],
#         [255, 230, 193],
#         ...,
#         [249, 230, 187],
#         [247, 231, 185],
#         [252, 236, 190]],
#
#        ...,
#
#        [[ 30,  26,  21],
#         [ 29,  25,  20],
#         [ 31,  27,  22],
#         ...,
#         [ 22,  25,  23],
#         [ 23,  26,  24],
#         [ 23,  26,  24]],
#
#        [[ 31,  27,  22],
#         [ 29,  25,  20],
#         [ 32,  28,  23],
#         ...,
#         [ 22,  25,  23],
#         [ 22,  25,  23],
#         [ 21,  24,  22]],
#
#        [[ 33,  29,  24],
#         [ 30,  26,  21],
#         [ 32,  28,  23],
# ...

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (2160, 3840, 3)

# %%
plt.imshow(img)

# %%
fix_img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
fix_img
# Out:
# array([[[194, 232, 253],
#         [193, 231, 252],
#         [192, 230, 251],
#         ...,
#         [191, 234, 253],
#         [189, 232, 249],
#         [192, 235, 252]],
#
#        [[192, 230, 253],
#         [192, 230, 253],
#         [192, 230, 253],
#         ...,
#         [188, 231, 250],
#         [187, 230, 247],
#         [190, 233, 250]],
#
#        [[192, 229, 255],
#         [192, 229, 255],
#         [193, 230, 255],
#         ...,
#         [187, 230, 249],
#         [185, 231, 247],
#         [190, 236, 252]],
#
#        ...,
#
#        [[ 21,  26,  30],
#         [ 20,  25,  29],
#         [ 22,  27,  31],
#         ...,
#         [ 23,  25,  22],
#         [ 24,  26,  23],
#         [ 24,  26,  23]],
#
#        [[ 22,  27,  31],
#         [ 20,  25,  29],
#         [ 23,  28,  32],
#         ...,
#         [ 23,  25,  22],
#         [ 23,  25,  22],
#         [ 22,  24,  21]],
#
#        [[ 24,  29,  33],
#         [ 21,  26,  30],
#         [ 23,  28,  32],
# ...

# %%
fix_img.shape
# Out:
# (2160, 3840, 3)

# %%
plt.imshow(fix_img)

# %%
img_gray= cv2.imread(r'C:\Users\niles\OneDrive\Pictures\134118367428608576.jpg', cv2.IMREAD_GRAYSCALE)

# %%
img_gray.shape
# Out:
# (2160, 3840)

# %%
img_gray
# Out:
# array([[223, 222, 221, ..., 223, 221, 224],
#        [221, 221, 221, ..., 220, 219, 222],
#        [221, 221, 222, ..., 219, 219, 224],
#        ...,
#        [ 25,  24,  26, ...,  24,  25,  25],
#        [ 26,  24,  27, ...,  24,  24,  23],
#        [ 28,  25,  27, ...,  24,  25,  25]],
#       shape=(2160, 3840), dtype=uint8)

# %%
img_gray.min()
# Out:
# np.uint8(5)

# %%
img_gray.max()
# Out:
# np.uint8(255)

# %%
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap= 'gray')

# %%
plt.imshow(img_gray, cmap= 'magma')

# %%
plt.imshow(img_gray, cmap='Accent')

# %%
plt.imshow(fix_img)

# %%
fix_img.shape
# Out:
# (2160, 3840, 3)

# %%
fix_img_1=cv2.resize(fix_img,(1080,1920)) # in this resize the omage are cut the pixal in devide by 2 and than we are print

# %%
fix_img_1
# Out:
# array([[[193, 231, 252],
#         [188, 226, 248],
#         [191, 227, 253],
#         ...,
#         [194, 236, 252],
#         [192, 234, 252],
#         [189, 232, 250]],
#
#        [[192, 230, 253],
#         [190, 228, 251],
#         [192, 228, 253],
#         ...,
#         [197, 239, 255],
#         [192, 235, 253],
#         [187, 230, 248]],
#
#        [[192, 229, 255],
#         [190, 230, 255],
#         [193, 229, 254],
#         ...,
#         [197, 239, 255],
#         [192, 236, 253],
#         [186, 231, 248]],
#
#        ...,
#
#        [[ 20,  25,  29],
#         [ 21,  26,  29],
#         [ 22,  26,  30],
#         ...,
#         [ 21,  23,  20],
#         [ 20,  22,  19],
#         [ 24,  26,  23]],
#
#        [[ 21,  26,  30],
#         [ 21,  26,  29],
#         [ 22,  26,  27],
#         ...,
#         [ 23,  25,  22],
#         [ 21,  23,  20],
#         [ 23,  25,  22]],
#
#        [[ 21,  26,  30],
#         [ 21,  26,  29],
#         [ 22,  26,  26],
# ...

# %%
w_ratio= 0.5 # in this we are assinign the width and hight to resize the imag 
h_ratio=0.5

# %%
fix_img_2 = cv2.resize(fix_img,(0,0),fix_img, w_ratio, h_ratio)

# %%
plt.imshow(fix_img_2)

# %%
img3= cv2.flip(fix_img_2,0)   # in this flip(0) is using the image flip to original to flip 
plt.imshow(img3)

# %%
img3= cv2.flip(fix_img_2,1)   # in this flip(1) is using the image on right  flip to original to flip 
plt.imshow(img3)

# %%
img3= cv2.flip(fix_img_2,-1)   # in this flip(-1) is using the image in left side flip to original to flip 
plt.imshow(img3)

# %% [markdown]
# # in this i am saveing the image

# %%
cv2.imwrite('new genai image.jpg',img3) # image savimnmg using the imwrite
# Out:
# True

# %%
pwd # is show the path
# Out:
# 'C:\\Users\\niles'

# %% [markdown]
# # img preprosecing with opencv
