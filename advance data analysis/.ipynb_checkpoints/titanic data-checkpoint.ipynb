# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\niles\Downloads\test.csv")

# %%
df1=pd.read_csv(r"C:\Users\niles\Downloads\train.csv")

# %%
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df['Age'].describe()
# Out:
# count    332.000000
# mean      30.272590
# std       14.181209
# min        0.170000
# 25%       21.000000
# 50%       27.000000
# 75%       39.000000
# max       76.000000
# Name: Age, dtype: float64

# %%
df['Age'].plot(kind='hist',bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Age'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df["Age"].skew() # is normaly distributed
# Out:
# np.float64(0.4573612871503845)

# %%
df['Age'].plot(kind='box')
# Out:
# <Axes: >

# %%
df[df['Age']>65]
# Out:
#     PassengerId  Pclass                                               Name  \
# 81          973       1                                 Straus, Mr. Isidor
# 96          988       1  Cavendish, Mrs. Tyrell William (Julia Florence...
#
#        Sex   Age  SibSp  Parch    Ticket      Fare    Cabin Embarked
# 81    male  67.0      1      0  PC 17483  221.7792  C55 C57        S
# 96  female  76.0      1      0     19877   78.8500      C46        S

# %%
len(df['Age'])
# Out:
# 418

# %%
df['Age'].isnull().sum()/len(df['Age']) * 100
# Out:
# np.float64(20.574162679425836)

# %% [raw]
# #--> conclusion is the
# #--> age is the normaly distrubuted
# #--> 20%  of the value is missing
# #--> there are some outliers

# %% [markdown]
# # fare

# %%
df['Fare'].describe()
# Out:
# count    417.000000
# mean      35.627188
# std       55.907576
# min        0.000000
# 25%        7.895800
# 50%       14.454200
# 75%       31.500000
# max      512.329200
# Name: Fare, dtype: float64

# %%
df['Fare'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Fare'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Fare'].skew()
# Out:
# np.float64(3.6872133081121405)

# %%
df['Fare'].plot(kind='box') # most outliers
# Out:
# <Axes: >

# %%
df[df['Fare'] >250]
# Out:
#      PassengerId  Pclass                                               Name  \
# 24           916       1    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)
# 53           945       1                         Fortune, Miss. Ethel Flora
# 59           951       1                        Chaudanson, Miss. Victorine
# 64           956       1                        Ryerson, Master. John Borie
# 69           961       1                Fortune, Mrs. Mark (Mary McDougald)
# 142         1034       1                         Ryerson, Mr. Arthur Larned
# 343         1235       1  Cardeza, Mrs. James Warburton Martinez (Charlo...
# 375         1267       1                           Bowen, Miss. Grace Scott
#
#         Sex   Age  SibSp  Parch    Ticket      Fare            Cabin Embarked
# 24   female  48.0      1      3  PC 17608  262.3750  B57 B59 B63 B66        C
# 53   female  28.0      3      2     19950  263.0000      C23 C25 C27        S
# ...

# %%
len(df['Fare'])
# Out:
# 418

# %%
df['Fare'].isnull().sum()
# Out:
# np.int64(1)

# %% [raw]
# # conclusions
# #-->the data is highly positive skewed
# #--> Fare col actually contains the group fare and not the individual fare
# #(This migth be and issue)
# #-->We need to create a new col called individual fare

# %% [markdown]
# # survived

# %%
df['Embarked'].value_counts()
# Out:
# Embarked
# S    270
# C    102
# Q     46
# Name: count, dtype: int64

# %%
df['Embarked'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Embarked'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Embarked'>

# %%
df['Embarked'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['Sex'].isnull().sum()
# Out:
# np.int64(0)

# %%
print(df['Sex'].dtype)
# Out:
# object

# %%
df['Sex']=df['Sex'].astype=(object)

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1[df1['Survived'] ==1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
sns.heatmap(pd.crosstab(df1['Survived'],df1['Pclass'],normalize='columns') * 100)
# Out:
# <Axes: xlabel='Pclass', ylabel='Survived'>

# %%
pd.crosstab(df1['Survived'],df1['Sex'],normalize='columns')*100
# Out:
# Sex          female       male
# Survived
# 0         25.796178  81.109185
# 1         74.203822  18.890815

# %%
pd.crosstab(df1['Survived'],df1['Embarked'],normalize='columns')*100
# Out:
# Embarked          C          Q          S
# Survived
# 0         44.642857  61.038961  66.304348
# 1         55.357143  38.961039  33.695652

# %%
pd.crosstab(df1['Sex'],df1['Embarked'],normalize='columns')*100
# Out:
# Embarked          C          Q          S
# Sex
# female    43.452381  46.753247  31.521739
# male      56.547619  53.246753  68.478261

# %%
pd.crosstab(df1['Pclass'],df1['Embarked'],normalize='columns')*100
# Out:
# Embarked          C          Q          S
# Pclass
# 1         50.595238   2.597403  19.720497
# 2         10.119048   3.896104  25.465839
# 3         39.285714  93.506494  54.813665
